# %% [markdown]
# 1. Extract the price history of ten commercial banks from the given api.
# https://www.nepalipaisa.com/api/GetStockHistory?stockSymbol=ADBL&fromDate=2025-04-19&toDate=2025-05-19&pageNo=1&itemsPerPage=10&pagePerDisplay=5&_=1747618698241
#
# 2. Save the data in .csv format.

# %%
import requests
import pandas as pd
url = "https://www.nepalipaisa.com/api/GetStockHistory?stockSymbol=ADBL&fromDate=2020-04-19&toDate=2025-05-19&pageNo=1&itemsPerPage=10&pagePerDisplay=5&_=1747618698241"
response = requests.get(url)
data = response.json()
stock_data = data.get("result", {}).get("data", [])
df = pd.DataFrame(stock_data)
df.to_csv("adbl_stock_history.csv", index=False)

# %%
import requests
import pandas as pd

def fetchStockData(symbol,start_date,end_date):
  url = f"https://www.nepalipaisa.com/api/GetStockHistory?stockSymbol={symbol}&fromDate={start_date}&toDate={end_date}&pageNo=1&itemsPerPage=1000&pagePerDisplay=5&_=1747618698241"
  response = requests.get(url)
  data = response.json()

  stock_data = data.get("result", {}).get("data", [])
  df = pd.DataFrame(stock_data)
  df.to_csv(f"{symbol}_stock_history.csv", index=False)

# %%
fetchStockData("NICA","2020-01-01","2025-01-01")

# %% [markdown]
# 3. Clean the data if necessary.

# %%
#cleaning the data

df=pd.read_csv("NICA_stock_history.csv")
df.head()
# Out:
#    sn            tradeDate tradeDateString  maxPrice  minPrice  closingPrice  \
# 0   1  2025-01-01T00:00:00      2025-01-01     388.0     377.3         383.6
# 1   2  2024-12-31T00:00:00      2024-12-31     395.0     376.6         385.0
# 2   3  2024-12-29T00:00:00      2024-12-29     404.7     391.0         391.0
# 3   4  2024-12-26T00:00:00      2024-12-26     409.9     388.0         403.0
# 4   5  2024-12-24T00:00:00      2024-12-24     398.0     390.0         396.0
#
#    noOfTransactions  volume      amount  previousClosing  differenceRs  \
# 0               291   43278  16613575.4            385.0          -1.4
# 1               784  132291  50756067.0            391.0          -6.0
# 2               528   70534  27876541.8            403.0         -12.0
# 3               632   92340  36962239.4            396.0           7.0
# 4               358   51143  20205178.7            388.8           7.2
#
#    percentChange
# 0          -0.36
# 1          -1.53
# 2          -2.98
# ...

# %%
isnull=df.isnull()
isnull_count= isnull.sum()
print(f"total number of null values {isnull_count}")
# Out:
# total number of null values sn                  0
# tradeDate           0
# tradeDateString     0
# maxPrice            0
# minPrice            0
# closingPrice        0
# noOfTransactions    0
# volume              0
# amount              0
# previousClosing     0
# differenceRs        0
# percentChange       0
# dtype: int64

# %%
fetchStockData("NABIL", "2020-01-01", "2025-01-01")

# %%
df = pd.read_csv("NABIL_stock_history.csv")
df.head()
# Out:
#    sn            tradeDate tradeDateString  maxPrice  minPrice  closingPrice  \
# 0   1  2025-01-01T00:00:00      2025-01-01     502.9     500.0         501.4
# 1   2  2024-12-31T00:00:00      2024-12-31     512.7     498.0         502.0
# 2   3  2024-12-29T00:00:00      2024-12-29     508.9     499.0         502.7
# 3   4  2024-12-26T00:00:00      2024-12-26     511.0     498.0         502.0
# 4   5  2024-12-24T00:00:00      2024-12-24     506.0     499.1         501.0
#
#    noOfTransactions  volume      amount  previousClosing  differenceRs  \
# 0               355   29808  14928274.4            502.0          -0.6
# 1               541   53222  26562216.3            502.7          -0.7
# 2               617   64296  32322538.0            502.0           0.7
# 3               897  127622  64123331.6            501.0           1.0
# 4               650   66517  33391369.2            501.0           0.0
#
#    percentChange
# 0          -0.12
# 1          -0.14
# 2           0.14
# ...

# %%
isnull=df.isnull()
isnull_count= isnull.sum()
print(f"total number of null values {isnull_count}")
# Out:
# total number of null values sn                  0
# tradeDate           0
# tradeDateString     0
# maxPrice            0
# minPrice            0
# closingPrice        0
# noOfTransactions    0
# volume              0
# amount              0
# previousClosing     0
# differenceRs        0
# percentChange       0
# dtype: int64

# %%
fetchStockData("SBI", "2020-01-01", "2025-01-01")

# %%
df = pd.read_csv("SBI_stock_history.csv")
df.head()
# Out:
#    sn            tradeDate tradeDateString  maxPrice  minPrice  closingPrice  \
# 0   1  2025-01-01T00:00:00      2025-01-01     435.0     419.6         420.1
# 1   2  2024-12-31T00:00:00      2024-12-31     428.0     421.1         428.0
# 2   3  2024-12-29T00:00:00      2024-12-29     442.0     428.0         430.0
# 3   4  2024-12-26T00:00:00      2024-12-26     439.6     421.0         435.0
# 4   5  2024-12-24T00:00:00      2024-12-24     453.0     422.1         425.0
#
#    noOfTransactions  volume      amount  previousClosing  differenceRs  \
# 0               102  102446  43123555.8            428.0          -7.9
# 1               117   29909  12668224.0            430.0          -2.0
# 2               135   40950  17717867.8            435.0          -5.0
# 3               169   47253  20458992.4            425.0          10.0
# 4               104   19353   8289472.6            427.8          -2.8
#
#    percentChange
# 0          -1.85
# 1          -0.47
# 2          -1.15
# ...

# %%
isnull=df.isnull()
isnull_count= isnull.sum()
print(f"total number of null values {isnull_count}")
# Out:
# total number of null values sn                  0
# tradeDate           0
# tradeDateString     0
# maxPrice            0
# minPrice            0
# closingPrice        0
# noOfTransactions    0
# volume              0
# amount              0
# previousClosing     0
# differenceRs        0
# percentChange       0
# dtype: int64

# %% [markdown]
# 4. Convert the daily to weekly format and plot it.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("SBI_stock_history.csv", parse_dates=["tradeDate"])


df.set_index("tradeDate", inplace=True)
df.sort_index(inplace=True)


weekly = pd.DataFrame()
weekly["closingPrice"] = df["closingPrice"].resample("W-FRI").last()
weekly["maxPrice"] = df["maxPrice"].resample("W-FRI").max()
weekly["minPrice"] = df["minPrice"].resample("W-FRI").min()
weekly["volume"] = df["volume"].resample("W-FRI").sum()
weekly["amount"] = df["amount"].resample("W-FRI").sum()
weekly["noOfTransactions"] = df["noOfTransactions"].resample("W-FRI").sum()


weekly.dropna(inplace=True)


plt.figure(figsize=(12, 6))
plt.plot(
    weekly.index,
    weekly["closingPrice"],
    color="#1f77b4",
    linewidth=2,
    label="SBI Weekly Closing Price"
)

plt.title("Weekly Closing Price - SBI Bank", fontsize=16, weight='bold')
plt.xlabel("Date", fontsize=12)
plt.ylabel("Price", fontsize=12)
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend()

# Add your name to the bottom right
plt.figtext(0.99, 0.01, "kalzang", ha="right", fontsize=20, color='Black')

plt.tight_layout()
plt.show()

# %% [markdown]
# 5. Convert the data to monthly format and plot it.

# %%
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv("SBI_stock_history.csv", parse_dates=["tradeDate"])


df.set_index("tradeDate", inplace=True)
df.sort_index(inplace=True)


monthly = pd.DataFrame()
monthly["closingPrice"] = df["closingPrice"].resample("M").last()
monthly["maxPrice"] = df["maxPrice"].resample("M").max()
monthly["minPrice"] = df["minPrice"].resample("M").min()
monthly["volume"] = df["volume"].resample("M").sum()
monthly["amount"] = df["amount"].resample("M").sum()
monthly["noOfTransactions"] = df["noOfTransactions"].resample("M").sum()


monthly.dropna(inplace=True)


plt.figure(figsize=(12, 6))
plt.plot(
    monthly.index,
    monthly["closingPrice"],
    color="#ff7f0e",
    linewidth=2,
    label="SBI Monthly Closing Price"
)

plt.title("Monthly Closing Price - SBI Bank", fontsize=16, weight='bold')
plt.xlabel("Date", fontsize=12)
plt.ylabel("Price", fontsize=12)
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend()

# Add your name to the bottom right
plt.figtext(0.99, 0.01, "kalzang", ha="right", fontsize=20, color='Black')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-2364087347.py:13: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly["closingPrice"] = df["closingPrice"].resample("M").last()
# /tmp/ipython-input-2364087347.py:14: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly["maxPrice"] = df["maxPrice"].resample("M").max()
# /tmp/ipython-input-2364087347.py:15: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly["minPrice"] = df["minPrice"].resample("M").min()
# /tmp/ipython-input-2364087347.py:16: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly["volume"] = df["volume"].resample("M").sum()
# /tmp/ipython-input-2364087347.py:17: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly["amount"] = df["amount"].resample("M").sum()
# ...

# %% [markdown]
# 6. Calculate the following technical indicators from the data and plot them.
#
#   a. Moving Average
#
#   b. Weighted Moving Average
#
#   c. RSI
#
#   d. OBV
#
#   e. CCI

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


df = pd.read_csv("SBI_stock_history.csv", parse_dates=["tradeDate"])
df.set_index("tradeDate", inplace=True)
df.sort_index(inplace=True)
df.dropna(inplace=True)

# %%
df['MA_20'] = df['closingPrice'].rolling(window=20).mean()

plt.figure(figsize=(12, 6))
plt.plot(df.index, df['closingPrice'], label='Closing Price', color='skyblue')
plt.plot(df.index, df['MA_20'], label='20-Day MA', color='orange', linewidth=2)
plt.title("Moving Average (20 Days) - SBI", fontsize=14)
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.grid(True)

# Add your name to the bottom right
plt.figtext(0.99, 0.01, "kalzang", ha="right", fontsize=20, color='Black')

plt.tight_layout()
plt.show()

# %%
def weighted_moving_average(data, window):
    weights = np.arange(1, window + 1)
    return data.rolling(window).apply(lambda prices: np.dot(prices, weights)/weights.sum(), raw=True)

df['WMA_20'] = weighted_moving_average(df['closingPrice'], 20)

plt.figure(figsize=(12, 6))
plt.plot(df.index, df['closingPrice'], label='Closing Price', color='gray')
plt.plot(df.index, df['WMA_20'], label='Weighted MA (20)', color='green', linewidth=2)
plt.title("Weighted Moving Average (20 Days) - SBI")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.grid(True)

# Add your name to the bottom right
plt.figtext(0.99, 0.01, "kalzang", ha="right", fontsize=20, color='Black')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv("SBI_stock_history.csv", parse_dates=["tradeDate"])


df.set_index("tradeDate", inplace=True)
df.sort_index(inplace=True)


def compute_rsi(series, period=14):
    delta = series.diff()
    gain = delta.where(delta > 0, 0)
    loss = -delta.where(delta < 0, 0)

    avg_gain = gain.rolling(window=period).mean()
    avg_loss = loss.rolling(window=period).mean()

    rs = avg_gain / avg_loss
    rsi = 100 - (100 / (1 + rs))
    return rsi

df["RSI_14"] = compute_rsi(df["closingPrice"])
df.dropna(subset=["RSI_14"], inplace=True)


plt.figure(figsize=(12, 6))
plt.plot(df.index, df["RSI_14"], label="RSI (14)", color="purple", linewidth=1.5)
plt.axhline(70, color="red", linestyle="--", label="Overbought (70)")
plt.axhline(30, color="green", linestyle="--", label="Oversold (30)")

plt.title("RSI (14 Days) - SBI Bank", fontsize=16, fontweight='bold')
plt.xlabel("Date")
plt.ylabel("RSI")
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()

# Add your name to the bottom right
plt.figtext(0.99, 0.01, "kalzang", ha="right", fontsize=20, color='Black')

plt.tight_layout()
plt.show()

# %%
df['OBV'] = (np.sign(df['closingPrice'].diff()) * df['volume']).fillna(0).cumsum()

plt.figure(figsize=(12, 6))
plt.plot(df.index, df['OBV'], color='darkblue', label='OBV')
plt.title("On-Balance Volume (OBV) - SBI")
plt.xlabel("Date")
plt.ylabel("OBV")
plt.grid(True)
plt.legend()

# Add your name to the bottom right
plt.figtext(0.99, 0.01, "kalzang", ha="left", fontsize=20, color='Black')

plt.tight_layout()
plt.show()

# %%
tp = (df['maxPrice'] + df['minPrice'] + df['closingPrice']) / 3
sma = tp.rolling(20).mean()
mad = tp.rolling(20).apply(lambda x: np.fabs(x - x.mean()).mean())
df['CCI'] = (tp - sma) / (0.015 * mad)

plt.figure(figsize=(12, 5))
plt.plot(df.index, df['CCI'], color='teal', label='CCI (20)')
plt.axhline(100, color='red', linestyle='--')
plt.axhline(-100, color='green', linestyle='--')
plt.title("Commodity Channel Index (CCI) - SBI")
plt.ylabel("CCI")
plt.grid(True)
plt.legend()

# Add your name to the bottom right
plt.figtext(0.99, 0.01, "kalzang", ha="left", fontsize=20, color='Black')

plt.tight_layout()
plt.show()
